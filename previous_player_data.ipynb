# %%
from nba_api.stats.static import teams
import pandas as pd
import numpy as np
import sqlite3
import rdata
from IPython.core.display import HTML
# %load_ext sql
# %reload_ext sql
# %sql sqlite:///../input/basketball/basketball.sqlite 

HTML("<script>Jupyter.notebook.kernel.restart()</script>")
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',200)
conn = sqlite3.connect("nba.db")
cursor = conn.cursor()
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# Traceback (most recent call last):
#   File "/Users/rohilverma/Library/Python/3.9/lib/python/site-packages/sqlalchemy/engine/base.py", line 143, in __init__
#     self._dbapi_connection = engine.raw_connection()
#   File "/Users/rohilverma/Library/Python/3.9/lib/python/site-packages/sqlalchemy/engine/base.py", line 3301, in raw_connection
#     return self.pool.connect()
#   File "/Users/rohilverma/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/base.py", line 447, in connect
#     return _ConnectionFairy._checkout(self)
#   File "/Users/rohilverma/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/base.py", line 1264, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "/Users/rohilverma/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/base.py", line 711, in checkout
#     rec = pool._do_get()
#   File "/Users/rohilverma/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/impl.py", line 178, in _do_get
#     self._dec_overflow()
#   File "/Users/rohilverma/Library/Python/3.9/lib/python/site-packages/sqlalchemy/util/langhelpers.py", line 224, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "/Users/rohilverma/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/impl.py", line 175, in _do_get
#     return self._create_connection()
#   File "/Users/rohilverma/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/base.py", line 388, in _create_connection
#     return _ConnectionRecord(self)
#   File "/Users/rohilverma/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/base.py", line 673, in __init__
#     self.__connect()
#   File "/Users/rohilverma/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/base.py", line 900, in __connect
#     pool.logger.debug("Error on connect(): %s", e)
#   File "/Users/rohilverma/Library/Python/3.9/lib/python/site-packages/sqlalchemy/util/langhelpers.py", line 224, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "/Users/rohilverma/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/base.py", line 895, in __connect
#     self.dbapi_connection = connection = pool._invoke_creator(self)
#   File "/Users/rohilverma/Library/Python/3.9/lib/python/site-packages/sqlalchemy/engine/create.py", line 661, in connect
#     return dialect.connect(*cargs, **cparams)
#   File "/Users/rohilverma/Library/Python/3.9/lib/python/site-packages/sqlalchemy/engine/default.py", line 629, in connect
#     return self.loaded_dbapi.connect(*cargs, **cparams)  # type: ignore[no-any-return]  # NOQA: E501
# sqlite3.OperationalError: unable to open database file
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/rohilverma/Library/Python/3.9/lib/python/site-packages/sql/magic.py", line 196, in execute
#     conn = sql.connection.Connection.set(
#   File "/Users/rohilverma/Library/Python/3.9/lib/python/site-packages/sql/connection.py", line 70, in set
#     cls.current = existing or Connection(descriptor, connect_args, creator)
#   File "/Users/rohilverma/Library/Python/3.9/lib/python/site-packages/sql/connection.py", line 55, in __init__
#     self.internal_connection = engine.connect()
#   File "/Users/rohilverma/Library/Python/3.9/lib/python/site-packages/sqlalchemy/engine/base.py", line 3277, in connect
#     return self._connection_cls(self)
#   File "/Users/rohilverma/Library/Python/3.9/lib/python/site-packages/sqlalchemy/engine/base.py", line 145, in __init__
#     Connection._handle_dbapi_exception_noconnection(
#   File "/Users/rohilverma/Library/Python/3.9/lib/python/site-packages/sqlalchemy/engine/base.py", line 2440, in _handle_dbapi_exception_noconnection
#     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#   File "/Users/rohilverma/Library/Python/3.9/lib/python/site-packages/sqlalchemy/engine/base.py", line 143, in __init__
#     self._dbapi_connection = engine.raw_connection()
#   File "/Users/rohilverma/Library/Python/3.9/lib/python/site-packages/sqlalchemy/engine/base.py", line 3301, in raw_connection
#     return self.pool.connect()
#   File "/Users/rohilverma/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/base.py", line 447, in connect
#     return _ConnectionFairy._checkout(self)
#   File "/Users/rohilverma/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/base.py", line 1264, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "/Users/rohilverma/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/base.py", line 711, in checkout
#     rec = pool._do_get()
#   File "/Users/rohilverma/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/impl.py", line 178, in _do_get
#     self._dec_overflow()
#   File "/Users/rohilverma/Library/Python/3.9/lib/python/site-packages/sqlalchemy/util/langhelpers.py", line 224, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "/Users/rohilverma/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/impl.py", line 175, in _do_get
#     return self._create_connection()
#   File "/Users/rohilverma/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/base.py", line 388, in _create_connection
#     return _ConnectionRecord(self)
#   File "/Users/rohilverma/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/base.py", line 673, in __init__
#     self.__connect()
#   File "/Users/rohilverma/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/base.py", line 900, in __connect
#     pool.logger.debug("Error on connect(): %s", e)
#   File "/Users/rohilverma/Library/Python/3.9/lib/python/site-packages/sqlalchemy/util/langhelpers.py", line 224, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "/Users/rohilverma/Library/Python/3.9/lib/python/site-packages/sqlalchemy/pool/base.py", line 895, in __connect
#     self.dbapi_connection = connection = pool._invoke_creator(self)
#   File "/Users/rohilverma/Library/Python/3.9/lib/python/site-packages/sqlalchemy/engine/create.py", line 661, in connect
#     return dialect.connect(*cargs, **cparams)
#   File "/Users/rohilverma/Library/Python/3.9/lib/python/site-packages/sqlalchemy/engine/default.py", line 629, in connect
#     return self.loaded_dbapi.connect(*cargs, **cparams)  # type: ignore[no-any-return]  # NOQA: E501
# sqlalchemy.exc.OperationalError: (sqlite3.OperationalError) unable to open database file
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys(['sqlite://'])

# %%
# %load_ext sql
# %sql --persist df
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
#  * sqlite://
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 get_ipython().run_line_magic('load_ext', 'sql')
# ----> 2 get_ipython().run_line_magic('sql', '--persist df')
#
# File ~/Library/Python/3.9/lib/python/site-packages/IPython/core/interactiveshell.py:2456, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2454     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2455 with self.builtin_trap:
# -> 2456     result = fn(*args, **kwargs)
#    2458 # The code below prevents the output from being displayed
#    2459 # when using magics with decorator @output_can_be_silenced
#    2460 # when the last Python token in the expression is a ';'.
#    2461 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/Library/Python/3.9/lib/python/site-packages/sql/magic.py:210, in SqlMagic.execute(self, line, cell, local_ns)
#     207     return None
#     209 if args.persist:
# --> 210     return self._persist_dataframe(parsed["sql"], conn, user_ns, append=False)
#     212 if args.append:
#     213     return self._persist_dataframe(parsed["sql"], conn, user_ns, append=True)
#
# File ~/Library/Python/3.9/lib/python/site-packages/sql/magic.py:276, in SqlMagic._persist_dataframe(self, raw, conn, user_ns, append)
#     274     raise SyntaxError("Syntax: %sql --persist <name_of_data_frame>")
#     275 try:
# --> 276     frame = eval(frame_name, user_ns)
#     277 except SyntaxError:
#     278     raise SyntaxError("Syntax: %sql --persist <name_of_data_frame>")
#
# File <string>:1
#
# NameError: name 'df' is not defined

# %%
df_games = %sql select * from game
# Out:
#  * sqlite://
# (sqlite3.OperationalError) no such table: game
# [SQL: select * from game]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
